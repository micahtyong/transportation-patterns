# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("Monthly_Transportation_Statistics.csv")
data.tail(20)
# Out:
#      Index                    Date  Air Safety - General Aviation Fatalities  \
# 884    884  09/01/2020 12:00:00 AM                                      51.0
# 885    885  10/01/2020 12:00:00 AM                                      22.0
# 886    886  11/01/2020 12:00:00 AM                                      25.0
# 887    887  12/01/2020 12:00:00 AM                                      17.0
# 888    888  01/01/2021 12:00:00 AM                                      11.0
# 889    889  02/01/2021 12:00:00 AM                                      25.0
# 890    890  03/01/2021 12:00:00 AM                                       7.0
# 891    891  04/01/2021 12:00:00 AM                                      34.0
# 892    892  05/01/2021 12:00:00 AM                                      33.0
# 893    893  06/01/2021 12:00:00 AM                                      33.0
# 894    894  07/01/2021 12:00:00 AM                                      51.0
# ...

# %%
data.shape
# Out:
# (77330, 15)

# %%
data = pd.read_csv("region_mobility_report_csvs/2022_ZW_Region_Mobility_Report.csv")
data.head(20)
# Out:
#    country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                   ZW       Zimbabwe          NaN          NaN         NaN
# 1                   ZW       Zimbabwe          NaN          NaN         NaN
# 2                   ZW       Zimbabwe          NaN          NaN         NaN
# 3                   ZW       Zimbabwe          NaN          NaN         NaN
# 4                   ZW       Zimbabwe          NaN          NaN         NaN
# 5                   ZW       Zimbabwe          NaN          NaN         NaN
# 6                   ZW       Zimbabwe          NaN          NaN         NaN
# 7                   ZW       Zimbabwe          NaN          NaN         NaN
# 8                   ZW       Zimbabwe          NaN          NaN         NaN
# 9                   ZW       Zimbabwe          NaN          NaN         NaN
# 10                  ZW       Zimbabwe          NaN          NaN         NaN
# ...

# %%
data.shape
# Out:
# (1473, 15)
