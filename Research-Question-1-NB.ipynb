# %% [markdown]
# # Transportation Analysis Notebook
#
# **Contributors:** Micah Yong, Annie Lin, Bongi Fleischer, Daniel Yamada

# %%
# Import statements
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import arviz as avz

# Modeling 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import scipy.stats as st
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor 
import pymc3 as pm
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from keras.models import Sequential
from keras.metrics import RootMeanSquaredError
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense, Activation, Flatten

# Hyperparameter tuning (commenting out for deliverable)
# import wandb
# from wandb.keras import WandbCallback

# Package settings
import os; os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
pd.options.mode.chained_assignment = None
random_state = 42
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-05-09 19:53:40.407501: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-09 19:53:40.407537: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Research Question 1: How well do transit ridership and infrastructure spending in the transportation sector predict GDP?

# %% [markdown]
# ## 2.3: EDA
#
# In this part, we will clean the monthly transportation statistics dataset.
# - We will normalize each column using [min-max normalization](https://en.wikipedia.org/wiki/Feature_scaling#Rescaling_(min-max_normalization)). We decided against other normalization techniques, such as [z-score normalization](https://en.wikipedia.org/wiki/Standard_score), because each input variable does not necessarily follow a normal distribution.
#
# Then, we will make initial observations about the data by building scatter plots for each feature against Real GDP and computing the corresponding correlation coefficient.

# %%
# Load in original dataframe 
data = pd.read_csv("Monthly_Transportation_Statistics.csv")

# We want to keep track of time 
metadata_columns = ["Date", "Index"]

# We want to compute GDP. We'll keep around employment statistics as sanity checks
output_columns = ["Real Gross Domestic Product - Seasonally Adjusted"]

# We will utilize measures of transportation ridership + transportation spending 
ridership_columns = [
    "Transit Ridership - Other Transit Modes - Adjusted",
    "Transit Ridership - Fixed Route Bus - Adjusted",
    "Transit Ridership - Urban Rail - Adjusted",
    "Passenger Rail Passengers",
    "Transportation Services Index - Passenger",
]

spending_columns = [
    "State and Local Government Construction Spending - Transportation",
    "State and Local Government Construction Spending - Mass Transit",
    "State and Local Government Construction Spending - Automotive",
]

prediction_columns = ridership_columns + spending_columns
all_columns = output_columns + prediction_columns 
original_df = data[all_columns]
df = data[all_columns]

# Create effective spending columns => average spending per month from the past 4 years
df = df.dropna(subset=spending_columns)
average_spending_columns = []

for spending_feature in spending_columns:
    average_five_year_spending = spending_feature + " (Mean)"
    average_spending_columns.append(average_five_year_spending)
    df[average_five_year_spending] = df[spending_feature].rolling(4 * 12, closed="left").mean()

df = df.dropna(subset=average_spending_columns)
df = df.drop(spending_columns, axis=1)
prediction_columns = ridership_columns + average_spending_columns

# Drop null values
y_val = "Real Gross Domestic Product - Seasonally Adjusted"
all_columns = output_columns + prediction_columns # + extra_output_columns
df = df.dropna(subset=all_columns)

# Normalize columns to a common scale (min-max scaling)
df = (df - df.min()) / (df.max() - df.min())

# %%
# Computing an estimate of correlation coefficient
def correlation_coefficient_estimate(x, y):
    """Returns the Pearson Correlation Coefficient Estimate amongst non-nan entries across x and y."""
    f = df[[x, y]]
    f = f.dropna()

    return sp.stats.pearsonr(f[x], f[y])[0]

# Plotting and tracking correlation estimates
correlations = []

for i, feature in enumerate(prediction_columns): 
    plt.figure(i)
    r = correlation_coefficient_estimate(feature, y_val)
    correlations.append((r, feature))
    sns.scatterplot(x=df[feature], y=df[y_val]).set(title="Correlation = " + str(r))
    
# Sort and output correlations from most correlated to least
correlations.sort(reverse=True, key=lambda x: abs(x[0]))
for r, feature in correlations:
    print(feature + " : " + str(r))
# Out:
# State and Local Government Construction Spending - Mass Transit (Mean) : 0.9602731314414302
# State and Local Government Construction Spending - Transportation (Mean) : 0.9484700572419957
# State and Local Government Construction Spending - Automotive (Mean) : -0.7325552534695297
# Transit Ridership - Fixed Route Bus - Adjusted : -0.5360949656480716
# Transit Ridership - Other Transit Modes - Adjusted : 0.303578228536764
# Transportation Services Index - Passenger : 0.07719010295170332
# Passenger Rail Passengers : 0.0450442644665541
# Transit Ridership - Urban Rail - Adjusted : 0.043868566476107484

# %%
# Rename dataframe columns (statsmodels and pymc3 doesn't allow attribute names with spaces)
rename_dict = {y_val: 'y'}
renamed_features = []
for i, col in enumerate(prediction_columns): 
    feat = "x" + str(i)
    rename_dict[col] = feat
    renamed_features.append(feat)
renamed_df = df.rename(columns=rename_dict)

# %% [markdown]
# # 2.6: Prediction with GLMs and nonparametric models

# %%
# If using WandB for Hyperparameter tuning, use this block
# wandb.init(project="transport", entity="micahtyong")
# config = wandb.config
# config.test_size = 0.3
# wandb.config.update(config)

# Otherwise, use this block for the reproducible deliverable
config = {}
config['test_size'] = 0.3

# %% [markdown]
# ## Frequentist Implementation of a Linear GLM using statsmodels
#
# In the next few code blocks, we will be creating a Linear GLM manually via `statsmodels`. Before that, we will mitigate multicollinearity by removing features with a [variance inflation factor (VIF)](https://www.statisticshowto.com/variance-inflation-factor/) greater than $6$.
# - According to [this data science article](https://quantifyinghealth.com/vif-threshold/), the typical VIF threshold for research papers is $!0$. However, since we are working with a smaller dataset, we opted for a more conservative threshold.
#
# See Appendex A.2 for a similar analysis using principal component analysis.

# %%
# Computing the VIF of each feature, then dropping columns with a VIF > threshold
def calculate_vif_(X, thresh=6.0, log=False):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            if log:
                print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    if log: 
        print('Remaining variables:')
        print(X.columns[variables])
    return X.iloc[:, variables]

prediction_columns_wo_colinearity = calculate_vif_(renamed_df[renamed_features], log=True)
# Out:
# dropping 'x2' at index: 2
# dropping 'x0' at index: 0
# dropping 'x6' at index: 4
# dropping 'x4' at index: 2
# dropping 'x3' at index: 1
# Remaining variables:
# Index(['x1', 'x5', 'x7'], dtype='object')

# %%
# Manually construct linear regression skeleton
train, test = train_test_split(renamed_df, test_size=config['test_size'])

# Compute formula with only the non-colinear variables; consider interaction variables
formula = f'y ~ ' + ' + '.join(prediction_columns_wo_colinearity)
print(formula)

# Construct model from formula 
glm_ = smf.glm(formula=formula,
              data=train,
              family=sm.families.Gaussian())
glm = glm_.fit()
glm.summary() # Passes pearson chi_squared test, but not log likelihood test
# Out:
# y ~ x1 + x5 + x7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   56
# Model:                            GLM   Df Residuals:                       52
# Model Family:                Gaussian   Df Model:                            3
# Link Function:               identity   Scale:                       0.0059934
# Method:                          IRLS   Log-Likelihood:                 65.893
# Date:                Mon, 09 May 2022   Deviance:                      0.31166
# Time:                        19:53:43   Pearson chi2:                    0.312
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1094      0.144      0.758      0.449      -0.174       0.393
# x1            -0.0083      0.110     -0.075      0.940      -0.223       0.207
# x5             0.9233      0.101      9.166      0.000       0.726       1.121
# x7            -0.0687      0.060     -1.141      0.254      -0.187       0.049
# ==============================================================================
# """

# %%
# Extracting RMSE
y_true = np.array(test['y'])
y_hat = glm.predict(test)
rmse_freq = sm.tools.eval_measures.rmse(y_true, y_hat)
rmse_freq
# Out:
# 0.09645930287120114

# %% [markdown]
# To quantify the uncertainty of our model results, we will use bootstrap.

# %%
# Bootstrapping the RMSE
values = df.values
n_iterations = 500
n_size = int(len(data) * 0.50) 

stats = []
for i in range(n_iterations):
    # Data splitting 
    renamed_df_iter = renamed_df.sample(frac=1, replace=True, random_state=random_state)
    train, test = train_test_split(renamed_df_iter, test_size=config['test_size'])
    
    # Mitigate multicollinearity w/ VIF
    prediction_columns_wo_colinearity_iter = calculate_vif_(renamed_df_iter[renamed_features])
    formula_iter = f'y ~ ' + ' + '.join(prediction_columns_wo_colinearity_iter)

    # Construct model from formula 
    glm_ = smf.glm(formula=formula_iter,
                  data=train,
                  family=sm.families.Gaussian())
    glm = glm_.fit()
    
    # Extract RMSE
    y_true = np.array(test['y'])
    y_hat = glm.predict(test)
    rmse_freq = sm.tools.eval_measures.rmse(y_true, y_hat)
    stats.append(rmse_freq)

# %%
# Plotting the range of MAE
plt.ylabel("Frequency")
plt.xlabel("RMSE")
plt.title("Distribution of Bootstrap Estimates of RMSE")
sns.distplot(stats)

# Construct 95% confidence interval
lower = np.percentile(stats, 2.5)
upper = np.percentile(stats, 97.5)
plt.plot((lower,upper),(1, 1),'ro-',color='orange')

# %%
# Interpreting Results
range_y = original_df[y_val].max() - original_df[y_val].min()
lower_val = lower * range_y
upper_val = upper * range_y
lower_val, upper_val
# Out:
# (1108154577362.7148, 1701143792947.626)

# %% [markdown]
# ### Bayesian implementation using Pymc3

# %%
# We can reuse the formula derived in the frequentist approach to construct a Bayesian GLM
print(formula)

bglm = pm.Model()

with bglm as gaussian_model:
    # Normally distributed priors
    family = pm.glm.families.Normal()
    # create the model 
    pm.GLM.from_formula(formula,data=renamed_df,family=family)
    # sample
    gaussian_trace = pm.sample(1000,return_inferencedata=True)
    
summary = avz.summary(gaussian_trace) 
print(summary)
# Out:
# y ~ x1 + x5 + x7
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, x7, x5, x1, Intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:13<00:00 Sampling 4 chains, 58 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 14 seconds.
# There were 55 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8970758202739325, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8900388816567751, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept -0.021  0.131  -0.286    0.211      0.006    0.005     480.0
# x1         0.111  0.093  -0.063    0.287      0.004    0.003     539.0
# x5         0.979  0.098   0.778    1.152      0.004    0.003     500.0
# x7        -0.039  0.060  -0.155    0.071      0.003    0.002     568.0
# sd         0.084  0.007   0.072    0.096      0.000    0.000     847.0
#
#            ess_tail  r_hat
# Intercept     421.0   1.02
# x1            409.0   1.02
# x5            449.0   1.02
# x7            445.0   1.02
# sd            662.0   1.00

# %%
# Draw posterior predictive samples from linear model 
chosen_features = list(prediction_columns_wo_colinearity.columns) 
with gaussian_model:
    gaussian_ppc = pm.sample_posterior_predictive(
        gaussian_trace, var_names = chosen_features + ['y'] + ['Intercept']
    )
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:07<00:00]
#     </div>

# %%
# Perform posterior predictive checking across all features
name_dict = {v: k for k, v in rename_dict.items()}
for col in chosen_features:
    # Compute the posterior regression function (y hat values) for the linear GLM
    y_hat_gaussian = np.exp(
        np.outer(gaussian_ppc[col], prediction_columns_wo_colinearity[col])
        + gaussian_ppc["Intercept"][:,np.newaxis]
    )
    
    # Plot posterior predictive checks, construct credible interval 
    _, ax = plt.subplots(figsize = (4,4))

    ax.plot(prediction_columns_wo_colinearity[col], df[y_val], "o", ms=4, alpha=0.4, label="Data")
    avz.plot_hdi(
        prediction_columns_wo_colinearity[col],
        y_hat_gaussian,
        ax=ax,
        hdi_prob=0.95,
        fill_kwargs={"alpha": 0.8, "label": "95% credible interval for reg fn"},
    )
    avz.plot_hdi(
        prediction_columns_wo_colinearity[col],
        gaussian_ppc["y"],
        ax=ax,
        hdi_prob=0.95,
        fill_kwargs={"alpha": 0.8, "color": "#a1dab4", "label": "95% credible interval for y_rep's"},
    )

    ax.set_xlabel(f"{name_dict[col]}")
    ax.set_ylabel("GDP (z-score)")
    ax.set_title("Posterior predictive checks")
    ax.legend(fontsize=10);

# %% [markdown]
# ### Part 3: Building a neural network to predict GDP

# %%
# Prepare Data (rely on neural network to perform dimensionality reduction)
df_nn = renamed_df
dataset = df_nn.values
X = dataset[:, 1:] # columns after 1st col are the input features 
Y = dataset[:,0:1] # 1st col (real GDP) is feature we want to predict 

# Split data into train, test, and validation 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=config['test_size'])

# %%
# Use this code block to tune hyperparameters using WandB
# wandb.init(project="transport", entity="micahtyong")
# config = wandb.config
# config.num_hidden_layers = 5
# config.input_units = 256
# config.hidden_units = 256
# config.epochs = 400
# config.batch_size = 32
# wandb.config.update(config)

# Use this code block for the reproducible deliverable
config['num_hidden_layers'] = 4
config['input_units'] = 256
config['hidden_units'] = 256
config['epochs'] = 700
config['batch_size'] = 16

# %%
# Set up model hyperparameters
NN_model = Sequential()

# The Input Layer : Takes in k features with a relu (nonlinear) activation function
NN_model.add(Dense(config['input_units'], kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers : To model interaction variables and more 
for i in range(config['num_hidden_layers']):
    NN_model.add(Dense(config['hidden_units'], kernel_initializer='normal',activation='relu'))

# The Output Layer : Return an estimate for real GDP
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Create RMSE loss function
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# Compile the network 
NN_model.compile(optimizer='adam',
    loss=root_mean_squared_error,
    metrics=[RootMeanSquaredError(), 'mean_absolute_error'])
NN_model.summary()
# Out:
# 2022-05-09 19:54:47.872514: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-09 19:54:47.872554: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-09 19:54:47.872580: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyter-micahtyong): /proc/driver/nvidia/version does not exist
# 2022-05-09 19:54:47.872987: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 265,729
# Trainable params: 265,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model to training data (segmenting a portion for validation)
NN_model.fit(X_train, Y_train, epochs=config['hidden_units'], batch_size=config['batch_size'],
             validation_split = 0.2, 
#              callbacks=[WandbCallback()]
            )
# Out:
# Epoch 1/256
# 2022-05-09 19:54:48.525370: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 3/3 [==============================] - 1s 118ms/step - loss: 0.5194 - root_mean_squared_error: 0.5204 - mean_absolute_error: 0.4441 - val_loss: 0.3987 - val_root_mean_squared_error: 0.3987 - val_mean_absolute_error: 0.3232
# Epoch 2/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3275 - root_mean_squared_error: 0.3516 - mean_absolute_error: 0.2789 - val_loss: 0.2895 - val_root_mean_squared_error: 0.2895 - val_mean_absolute_error: 0.2595
# Epoch 3/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3020 - root_mean_squared_error: 0.3025 - mean_absolute_error: 0.2696 - val_loss: 0.2052 - val_root_mean_squared_error: 0.2052 - val_mean_absolute_error: 0.1747
# Epoch 4/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1858 - root_mean_squared_error: 0.1884 - mean_absolute_error: 0.1557 - val_loss: 0.1924 - val_root_mean_squared_error: 0.1924 - val_mean_absolute_error: 0.1423
# Epoch 5/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1830 - root_mean_squared_error: 0.1845 - mean_absolute_error: 0.1454 - val_loss: 0.1080 - val_root_mean_squared_error: 0.1080 - val_mean_absolute_error: 0.0899
# Epoch 6/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1039 - root_mean_squared_error: 0.1054 - mean_absolute_error: 0.0844 - val_loss: 0.1076 - val_root_mean_squared_error: 0.1076 - val_mean_absolute_error: 0.0966
# Epoch 7/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0986 - root_mean_squared_error: 0.0999 - mean_absolute_error: 0.0825 - val_loss: 0.0927 - val_root_mean_squared_error: 0.0927 - val_mean_absolute_error: 0.0763
# Epoch 8/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0997 - root_mean_squared_error: 0.1000 - mean_absolute_error: 0.0828 - val_loss: 0.1041 - val_root_mean_squared_error: 0.1041 - val_mean_absolute_error: 0.0930
# Epoch 9/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0987 - root_mean_squared_error: 0.0989 - mean_absolute_error: 0.0877 - val_loss: 0.0552 - val_root_mean_squared_error: 0.0552 - val_mean_absolute_error: 0.0356
# Epoch 10/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0924 - root_mean_squared_error: 0.0934 - mean_absolute_error: 0.0771 - val_loss: 0.0632 - val_root_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.0406
# Epoch 11/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0850 - root_mean_squared_error: 0.0862 - mean_absolute_error: 0.0750 - val_loss: 0.0999 - val_root_mean_squared_error: 0.0999 - val_mean_absolute_error: 0.0904
# Epoch 12/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0896 - root_mean_squared_error: 0.0906 - mean_absolute_error: 0.0806 - val_loss: 0.0578 - val_root_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.0399
# Epoch 13/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0701 - root_mean_squared_error: 0.0707 - mean_absolute_error: 0.0594 - val_loss: 0.0568 - val_root_mean_squared_error: 0.0568 - val_mean_absolute_error: 0.0534
# Epoch 14/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0668 - root_mean_squared_error: 0.0668 - mean_absolute_error: 0.0564 - val_loss: 0.0411 - val_root_mean_squared_error: 0.0411 - val_mean_absolute_error: 0.0294
# Epoch 15/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0653 - root_mean_squared_error: 0.0660 - mean_absolute_error: 0.0540 - val_loss: 0.0472 - val_root_mean_squared_error: 0.0472 - val_mean_absolute_error: 0.0435
# Epoch 16/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0606 - root_mean_squared_error: 0.0609 - mean_absolute_error: 0.0511 - val_loss: 0.0417 - val_root_mean_squared_error: 0.0417 - val_mean_absolute_error: 0.0374
# Epoch 17/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0588 - root_mean_squared_error: 0.0589 - mean_absolute_error: 0.0480 - val_loss: 0.0477 - val_root_mean_squared_error: 0.0477 - val_mean_absolute_error: 0.0455
# Epoch 18/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0561 - root_mean_squared_error: 0.0567 - mean_absolute_error: 0.0471 - val_loss: 0.0449 - val_root_mean_squared_error: 0.0449 - val_mean_absolute_error: 0.0406
# Epoch 19/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0519 - root_mean_squared_error: 0.0519 - mean_absolute_error: 0.0453 - val_loss: 0.0483 - val_root_mean_squared_error: 0.0483 - val_mean_absolute_error: 0.0442
# Epoch 20/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0499 - root_mean_squared_error: 0.0500 - mean_absolute_error: 0.0445 - val_loss: 0.0493 - val_root_mean_squared_error: 0.0493 - val_mean_absolute_error: 0.0463
# Epoch 21/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0506 - root_mean_squared_error: 0.0518 - mean_absolute_error: 0.0426 - val_loss: 0.0459 - val_root_mean_squared_error: 0.0459 - val_mean_absolute_error: 0.0411
# Epoch 22/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0501 - root_mean_squared_error: 0.0514 - mean_absolute_error: 0.0397 - val_loss: 0.0385 - val_root_mean_squared_error: 0.0385 - val_mean_absolute_error: 0.0329
# Epoch 23/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0465 - root_mean_squared_error: 0.0466 - mean_absolute_error: 0.0377 - val_loss: 0.0396 - val_root_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.0302
# Epoch 24/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0466 - root_mean_squared_error: 0.0473 - mean_absolute_error: 0.0391 - val_loss: 0.0744 - val_root_mean_squared_error: 0.0744 - val_mean_absolute_error: 0.0692
# Epoch 25/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0625 - root_mean_squared_error: 0.0635 - mean_absolute_error: 0.0552 - val_loss: 0.0455 - val_root_mean_squared_error: 0.0455 - val_mean_absolute_error: 0.0349
# Epoch 26/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0445 - root_mean_squared_error: 0.0446 - mean_absolute_error: 0.0361 - val_loss: 0.0416 - val_root_mean_squared_error: 0.0416 - val_mean_absolute_error: 0.0370
# Epoch 27/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0415 - root_mean_squared_error: 0.0422 - mean_absolute_error: 0.0338 - val_loss: 0.0361 - val_root_mean_squared_error: 0.0361 - val_mean_absolute_error: 0.0302
# Epoch 28/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0397 - root_mean_squared_error: 0.0401 - mean_absolute_error: 0.0332 - val_loss: 0.0380 - val_root_mean_squared_error: 0.0380 - val_mean_absolute_error: 0.0332
# Epoch 29/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0356 - root_mean_squared_error: 0.0357 - mean_absolute_error: 0.0306 - val_loss: 0.0428 - val_root_mean_squared_error: 0.0428 - val_mean_absolute_error: 0.0357
# Epoch 30/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0426 - root_mean_squared_error: 0.0442 - mean_absolute_error: 0.0374 - val_loss: 0.0385 - val_root_mean_squared_error: 0.0385 - val_mean_absolute_error: 0.0299
# Epoch 31/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0393 - root_mean_squared_error: 0.0394 - mean_absolute_error: 0.0334 - val_loss: 0.0398 - val_root_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.0294
# Epoch 32/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0413 - root_mean_squared_error: 0.0441 - mean_absolute_error: 0.0334 - val_loss: 0.0742 - val_root_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.0685
# Epoch 33/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0515 - root_mean_squared_error: 0.0540 - mean_absolute_error: 0.0456 - val_loss: 0.0584 - val_root_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.0456
# Epoch 34/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0487 - root_mean_squared_error: 0.0499 - mean_absolute_error: 0.0405 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0662 - val_mean_absolute_error: 0.0591
# Epoch 35/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0461 - root_mean_squared_error: 0.0475 - mean_absolute_error: 0.0383 - val_loss: 0.0727 - val_root_mean_squared_error: 0.0727 - val_mean_absolute_error: 0.0593
# Epoch 36/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0525 - root_mean_squared_error: 0.0528 - mean_absolute_error: 0.0427 - val_loss: 0.0797 - val_root_mean_squared_error: 0.0797 - val_mean_absolute_error: 0.0706
# Epoch 37/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0606 - root_mean_squared_error: 0.0616 - mean_absolute_error: 0.0486 - val_loss: 0.0753 - val_root_mean_squared_error: 0.0753 - val_mean_absolute_error: 0.0644
# Epoch 38/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0534 - root_mean_squared_error: 0.0574 - mean_absolute_error: 0.0460 - val_loss: 0.0682 - val_root_mean_squared_error: 0.0682 - val_mean_absolute_error: 0.0573
# Epoch 39/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0500 - root_mean_squared_error: 0.0518 - mean_absolute_error: 0.0403 - val_loss: 0.0424 - val_root_mean_squared_error: 0.0424 - val_mean_absolute_error: 0.0325
# Epoch 40/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0408 - root_mean_squared_error: 0.0417 - mean_absolute_error: 0.0332 - val_loss: 0.0435 - val_root_mean_squared_error: 0.0435 - val_mean_absolute_error: 0.0335
# Epoch 41/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0321 - root_mean_squared_error: 0.0328 - mean_absolute_error: 0.0270 - val_loss: 0.0392 - val_root_mean_squared_error: 0.0392 - val_mean_absolute_error: 0.0348
# Epoch 42/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0291 - root_mean_squared_error: 0.0295 - mean_absolute_error: 0.0249 - val_loss: 0.0425 - val_root_mean_squared_error: 0.0425 - val_mean_absolute_error: 0.0319
# Epoch 43/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0378 - root_mean_squared_error: 0.0381 - mean_absolute_error: 0.0303 - val_loss: 0.0331 - val_root_mean_squared_error: 0.0331 - val_mean_absolute_error: 0.0276
# Epoch 44/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0316 - root_mean_squared_error: 0.0321 - mean_absolute_error: 0.0260 - val_loss: 0.0374 - val_root_mean_squared_error: 0.0374 - val_mean_absolute_error: 0.0333
# Epoch 45/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0316 - root_mean_squared_error: 0.0323 - mean_absolute_error: 0.0271 - val_loss: 0.0454 - val_root_mean_squared_error: 0.0454 - val_mean_absolute_error: 0.0351
# Epoch 46/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0372 - root_mean_squared_error: 0.0378 - mean_absolute_error: 0.0303 - val_loss: 0.0432 - val_root_mean_squared_error: 0.0432 - val_mean_absolute_error: 0.0308
# Epoch 47/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0368 - root_mean_squared_error: 0.0370 - mean_absolute_error: 0.0309 - val_loss: 0.0387 - val_root_mean_squared_error: 0.0387 - val_mean_absolute_error: 0.0339
# Epoch 48/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0291 - root_mean_squared_error: 0.0295 - mean_absolute_error: 0.0235 - val_loss: 0.0491 - val_root_mean_squared_error: 0.0491 - val_mean_absolute_error: 0.0393
# Epoch 49/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0447 - root_mean_squared_error: 0.0458 - mean_absolute_error: 0.0353 - val_loss: 0.0406 - val_root_mean_squared_error: 0.0406 - val_mean_absolute_error: 0.0331
# Epoch 50/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0339 - root_mean_squared_error: 0.0354 - mean_absolute_error: 0.0279 - val_loss: 0.0424 - val_root_mean_squared_error: 0.0424 - val_mean_absolute_error: 0.0323
# Epoch 51/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0379 - root_mean_squared_error: 0.0380 - mean_absolute_error: 0.0311 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0320 - val_mean_absolute_error: 0.0280
# Epoch 52/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0464 - root_mean_squared_error: 0.0491 - mean_absolute_error: 0.0404 - val_loss: 0.0355 - val_root_mean_squared_error: 0.0355 - val_mean_absolute_error: 0.0302
# Epoch 53/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0387 - root_mean_squared_error: 0.0401 - mean_absolute_error: 0.0337 - val_loss: 0.0437 - val_root_mean_squared_error: 0.0437 - val_mean_absolute_error: 0.0319
# Epoch 54/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0344 - root_mean_squared_error: 0.0347 - mean_absolute_error: 0.0262 - val_loss: 0.0529 - val_root_mean_squared_error: 0.0529 - val_mean_absolute_error: 0.0435
# Epoch 55/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0344 - root_mean_squared_error: 0.0368 - mean_absolute_error: 0.0285 - val_loss: 0.0515 - val_root_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.0412
# Epoch 56/256
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0382 - root_mean_squared_error: 0.0398 - mean_absolute_error: 0.0316 - val_loss: 0.0407 - val_root_mean_squared_error: 0.0407 - val_mean_absolute_error: 0.0318
# Epoch 57/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0352 - root_mean_squared_error: 0.0352 - mean_absolute_error: 0.0289 - val_loss: 0.0370 - val_root_mean_squared_error: 0.0370 - val_mean_absolute_error: 0.0258
# Epoch 58/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0298 - root_mean_squared_error: 0.0299 - mean_absolute_error: 0.0234 - val_loss: 0.0348 - val_root_mean_squared_error: 0.0348 - val_mean_absolute_error: 0.0296
# Epoch 59/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0217 - root_mean_squared_error: 0.0217 - mean_absolute_error: 0.0188 - val_loss: 0.0367 - val_root_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.0302
# Epoch 60/256
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0233 - root_mean_squared_error: 0.0237 - mean_absolute_error: 0.0183 - val_loss: 0.0381 - val_root_mean_squared_error: 0.0381 - val_mean_absolute_error: 0.0295
# Epoch 61/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0259 - root_mean_squared_error: 0.0265 - mean_absolute_error: 0.0195 - val_loss: 0.0354 - val_root_mean_squared_error: 0.0354 - val_mean_absolute_error: 0.0295
# Epoch 62/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0238 - root_mean_squared_error: 0.0239 - mean_absolute_error: 0.0179 - val_loss: 0.0463 - val_root_mean_squared_error: 0.0463 - val_mean_absolute_error: 0.0355
# Epoch 63/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0292 - root_mean_squared_error: 0.0308 - mean_absolute_error: 0.0244 - val_loss: 0.0367 - val_root_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.0271
# Epoch 64/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0244 - root_mean_squared_error: 0.0247 - mean_absolute_error: 0.0195 - val_loss: 0.0398 - val_root_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.0292
# Epoch 65/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0274 - root_mean_squared_error: 0.0276 - mean_absolute_error: 0.0215 - val_loss: 0.0343 - val_root_mean_squared_error: 0.0343 - val_mean_absolute_error: 0.0285
# Epoch 66/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0204 - root_mean_squared_error: 0.0209 - mean_absolute_error: 0.0163 - val_loss: 0.0348 - val_root_mean_squared_error: 0.0348 - val_mean_absolute_error: 0.0259
# Epoch 67/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0210 - root_mean_squared_error: 0.0217 - mean_absolute_error: 0.0155 - val_loss: 0.0319 - val_root_mean_squared_error: 0.0319 - val_mean_absolute_error: 0.0246
# Epoch 68/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0236 - root_mean_squared_error: 0.0237 - mean_absolute_error: 0.0173 - val_loss: 0.0357 - val_root_mean_squared_error: 0.0357 - val_mean_absolute_error: 0.0270
# Epoch 69/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0213 - root_mean_squared_error: 0.0215 - mean_absolute_error: 0.0163 - val_loss: 0.0368 - val_root_mean_squared_error: 0.0368 - val_mean_absolute_error: 0.0275
# Epoch 70/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0213 - root_mean_squared_error: 0.0216 - mean_absolute_error: 0.0166 - val_loss: 0.0356 - val_root_mean_squared_error: 0.0356 - val_mean_absolute_error: 0.0274
# Epoch 71/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0286 - root_mean_squared_error: 0.0303 - mean_absolute_error: 0.0245 - val_loss: 0.0524 - val_root_mean_squared_error: 0.0524 - val_mean_absolute_error: 0.0398
# Epoch 72/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0353 - root_mean_squared_error: 0.0360 - mean_absolute_error: 0.0270 - val_loss: 0.0611 - val_root_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.0533
# Epoch 73/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0537 - root_mean_squared_error: 0.0551 - mean_absolute_error: 0.0454 - val_loss: 0.0594 - val_root_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.0501
# Epoch 74/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0647 - root_mean_squared_error: 0.0650 - mean_absolute_error: 0.0579 - val_loss: 0.0388 - val_root_mean_squared_error: 0.0388 - val_mean_absolute_error: 0.0307
# Epoch 75/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0480 - root_mean_squared_error: 0.0506 - mean_absolute_error: 0.0420 - val_loss: 0.0398 - val_root_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.0312
# Epoch 76/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0387 - root_mean_squared_error: 0.0392 - mean_absolute_error: 0.0318 - val_loss: 0.0432 - val_root_mean_squared_error: 0.0432 - val_mean_absolute_error: 0.0321
# Epoch 77/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0320 - root_mean_squared_error: 0.0326 - mean_absolute_error: 0.0272 - val_loss: 0.0331 - val_root_mean_squared_error: 0.0331 - val_mean_absolute_error: 0.0287
# Epoch 78/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0238 - root_mean_squared_error: 0.0239 - mean_absolute_error: 0.0196 - val_loss: 0.0326 - val_root_mean_squared_error: 0.0326 - val_mean_absolute_error: 0.0275
# Epoch 79/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0316 - root_mean_squared_error: 0.0324 - mean_absolute_error: 0.0251 - val_loss: 0.0355 - val_root_mean_squared_error: 0.0355 - val_mean_absolute_error: 0.0295
# Epoch 80/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0235 - root_mean_squared_error: 0.0236 - mean_absolute_error: 0.0180 - val_loss: 0.0470 - val_root_mean_squared_error: 0.0470 - val_mean_absolute_error: 0.0381
# Epoch 81/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0309 - root_mean_squared_error: 0.0312 - mean_absolute_error: 0.0262 - val_loss: 0.0511 - val_root_mean_squared_error: 0.0511 - val_mean_absolute_error: 0.0410
# Epoch 82/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0308 - root_mean_squared_error: 0.0330 - mean_absolute_error: 0.0261 - val_loss: 0.0742 - val_root_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.0673
# Epoch 83/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0724 - root_mean_squared_error: 0.0760 - mean_absolute_error: 0.0666 - val_loss: 0.0439 - val_root_mean_squared_error: 0.0439 - val_mean_absolute_error: 0.0322
# Epoch 84/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0485 - root_mean_squared_error: 0.0523 - mean_absolute_error: 0.0420 - val_loss: 0.0341 - val_root_mean_squared_error: 0.0341 - val_mean_absolute_error: 0.0273
# Epoch 85/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0481 - root_mean_squared_error: 0.0528 - mean_absolute_error: 0.0405 - val_loss: 0.0475 - val_root_mean_squared_error: 0.0475 - val_mean_absolute_error: 0.0371
# Epoch 86/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0466 - root_mean_squared_error: 0.0490 - mean_absolute_error: 0.0393 - val_loss: 0.0548 - val_root_mean_squared_error: 0.0548 - val_mean_absolute_error: 0.0425
# Epoch 87/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0382 - root_mean_squared_error: 0.0401 - mean_absolute_error: 0.0328 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0662 - val_mean_absolute_error: 0.0601
# Epoch 88/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0463 - root_mean_squared_error: 0.0479 - mean_absolute_error: 0.0386 - val_loss: 0.0664 - val_root_mean_squared_error: 0.0664 - val_mean_absolute_error: 0.0584
# Epoch 89/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0496 - root_mean_squared_error: 0.0515 - mean_absolute_error: 0.0432 - val_loss: 0.0537 - val_root_mean_squared_error: 0.0537 - val_mean_absolute_error: 0.0456
# Epoch 90/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0460 - root_mean_squared_error: 0.0475 - mean_absolute_error: 0.0398 - val_loss: 0.0534 - val_root_mean_squared_error: 0.0534 - val_mean_absolute_error: 0.0400
# Epoch 91/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0483 - root_mean_squared_error: 0.0487 - mean_absolute_error: 0.0395 - val_loss: 0.0398 - val_root_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.0316
# Epoch 92/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0407 - root_mean_squared_error: 0.0416 - mean_absolute_error: 0.0356 - val_loss: 0.0400 - val_root_mean_squared_error: 0.0400 - val_mean_absolute_error: 0.0291
# Epoch 93/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0313 - root_mean_squared_error: 0.0315 - mean_absolute_error: 0.0246 - val_loss: 0.0333 - val_root_mean_squared_error: 0.0333 - val_mean_absolute_error: 0.0288
# Epoch 94/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0246 - root_mean_squared_error: 0.0249 - mean_absolute_error: 0.0199 - val_loss: 0.0364 - val_root_mean_squared_error: 0.0364 - val_mean_absolute_error: 0.0289
# Epoch 95/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0313 - root_mean_squared_error: 0.0335 - mean_absolute_error: 0.0259 - val_loss: 0.0368 - val_root_mean_squared_error: 0.0368 - val_mean_absolute_error: 0.0255
# Epoch 96/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0295 - root_mean_squared_error: 0.0303 - mean_absolute_error: 0.0230 - val_loss: 0.0460 - val_root_mean_squared_error: 0.0460 - val_mean_absolute_error: 0.0359
# Epoch 97/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0290 - root_mean_squared_error: 0.0296 - mean_absolute_error: 0.0246 - val_loss: 0.0543 - val_root_mean_squared_error: 0.0543 - val_mean_absolute_error: 0.0456
# Epoch 98/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0403 - root_mean_squared_error: 0.0416 - mean_absolute_error: 0.0365 - val_loss: 0.0400 - val_root_mean_squared_error: 0.0400 - val_mean_absolute_error: 0.0308
# Epoch 99/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0292 - root_mean_squared_error: 0.0294 - mean_absolute_error: 0.0238 - val_loss: 0.0484 - val_root_mean_squared_error: 0.0484 - val_mean_absolute_error: 0.0354
# Epoch 100/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0362 - root_mean_squared_error: 0.0369 - mean_absolute_error: 0.0278 - val_loss: 0.0412 - val_root_mean_squared_error: 0.0412 - val_mean_absolute_error: 0.0288
# Epoch 101/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0251 - root_mean_squared_error: 0.0252 - mean_absolute_error: 0.0197 - val_loss: 0.0405 - val_root_mean_squared_error: 0.0405 - val_mean_absolute_error: 0.0279
# Epoch 102/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0283 - root_mean_squared_error: 0.0290 - mean_absolute_error: 0.0238 - val_loss: 0.0372 - val_root_mean_squared_error: 0.0372 - val_mean_absolute_error: 0.0277
# Epoch 103/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0305 - root_mean_squared_error: 0.0315 - mean_absolute_error: 0.0247 - val_loss: 0.0367 - val_root_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.0311
# Epoch 104/256
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0237 - root_mean_squared_error: 0.0244 - mean_absolute_error: 0.0172 - val_loss: 0.0289 - val_root_mean_squared_error: 0.0289 - val_mean_absolute_error: 0.0239
# Epoch 105/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0219 - root_mean_squared_error: 0.0225 - mean_absolute_error: 0.0174 - val_loss: 0.0311 - val_root_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.0255
# Epoch 106/256
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0201 - root_mean_squared_error: 0.0204 - mean_absolute_error: 0.0164 - val_loss: 0.0334 - val_root_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.0278
# Epoch 107/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0198 - root_mean_squared_error: 0.0203 - mean_absolute_error: 0.0151 - val_loss: 0.0328 - val_root_mean_squared_error: 0.0328 - val_mean_absolute_error: 0.0271
# Epoch 108/256
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0247 - root_mean_squared_error: 0.0248 - mean_absolute_error: 0.0203 - val_loss: 0.0330 - val_root_mean_squared_error: 0.0330 - val_mean_absolute_error: 0.0259
# Epoch 109/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0226 - root_mean_squared_error: 0.0229 - mean_absolute_error: 0.0183 - val_loss: 0.0384 - val_root_mean_squared_error: 0.0384 - val_mean_absolute_error: 0.0286
# Epoch 110/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0215 - root_mean_squared_error: 0.0222 - mean_absolute_error: 0.0164 - val_loss: 0.0315 - val_root_mean_squared_error: 0.0315 - val_mean_absolute_error: 0.0245
# Epoch 111/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0196 - root_mean_squared_error: 0.0197 - mean_absolute_error: 0.0158 - val_loss: 0.0316 - val_root_mean_squared_error: 0.0316 - val_mean_absolute_error: 0.0261
# Epoch 112/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0186 - root_mean_squared_error: 0.0187 - mean_absolute_error: 0.0151 - val_loss: 0.0325 - val_root_mean_squared_error: 0.0325 - val_mean_absolute_error: 0.0253
# Epoch 113/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0211 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0181 - val_loss: 0.0329 - val_root_mean_squared_error: 0.0329 - val_mean_absolute_error: 0.0276
# Epoch 114/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0184 - root_mean_squared_error: 0.0185 - mean_absolute_error: 0.0137 - val_loss: 0.0340 - val_root_mean_squared_error: 0.0340 - val_mean_absolute_error: 0.0283
# Epoch 115/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0209 - root_mean_squared_error: 0.0209 - mean_absolute_error: 0.0151 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0322 - val_mean_absolute_error: 0.0261
# Epoch 116/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0191 - root_mean_squared_error: 0.0192 - mean_absolute_error: 0.0146 - val_loss: 0.0469 - val_root_mean_squared_error: 0.0469 - val_mean_absolute_error: 0.0386
# Epoch 117/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0299 - root_mean_squared_error: 0.0309 - mean_absolute_error: 0.0249 - val_loss: 0.0445 - val_root_mean_squared_error: 0.0445 - val_mean_absolute_error: 0.0357
# Epoch 118/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0305 - root_mean_squared_error: 0.0319 - mean_absolute_error: 0.0264 - val_loss: 0.0438 - val_root_mean_squared_error: 0.0438 - val_mean_absolute_error: 0.0350
# Epoch 119/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0300 - root_mean_squared_error: 0.0306 - mean_absolute_error: 0.0251 - val_loss: 0.0465 - val_root_mean_squared_error: 0.0465 - val_mean_absolute_error: 0.0367
# Epoch 120/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0356 - root_mean_squared_error: 0.0383 - mean_absolute_error: 0.0307 - val_loss: 0.0574 - val_root_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.0468
# Epoch 121/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0369 - root_mean_squared_error: 0.0375 - mean_absolute_error: 0.0302 - val_loss: 0.0450 - val_root_mean_squared_error: 0.0450 - val_mean_absolute_error: 0.0369
# Epoch 122/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0257 - root_mean_squared_error: 0.0283 - mean_absolute_error: 0.0216 - val_loss: 0.0383 - val_root_mean_squared_error: 0.0383 - val_mean_absolute_error: 0.0323
# Epoch 123/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0344 - root_mean_squared_error: 0.0357 - mean_absolute_error: 0.0281 - val_loss: 0.0310 - val_root_mean_squared_error: 0.0310 - val_mean_absolute_error: 0.0237
# Epoch 124/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0297 - root_mean_squared_error: 0.0304 - mean_absolute_error: 0.0224 - val_loss: 0.0365 - val_root_mean_squared_error: 0.0365 - val_mean_absolute_error: 0.0314
# Epoch 125/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0269 - root_mean_squared_error: 0.0271 - mean_absolute_error: 0.0219 - val_loss: 0.0334 - val_root_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.0281
# Epoch 126/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0229 - root_mean_squared_error: 0.0234 - mean_absolute_error: 0.0201 - val_loss: 0.0324 - val_root_mean_squared_error: 0.0324 - val_mean_absolute_error: 0.0236
# Epoch 127/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0243 - root_mean_squared_error: 0.0248 - mean_absolute_error: 0.0193 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0322 - val_mean_absolute_error: 0.0281
# Epoch 128/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0177 - root_mean_squared_error: 0.0179 - mean_absolute_error: 0.0141 - val_loss: 0.0356 - val_root_mean_squared_error: 0.0356 - val_mean_absolute_error: 0.0299
# Epoch 129/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0262 - root_mean_squared_error: 0.0273 - mean_absolute_error: 0.0225 - val_loss: 0.0360 - val_root_mean_squared_error: 0.0360 - val_mean_absolute_error: 0.0311
# Epoch 130/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0306 - root_mean_squared_error: 0.0310 - mean_absolute_error: 0.0247 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0337 - val_mean_absolute_error: 0.0280
# Epoch 131/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0173 - root_mean_squared_error: 0.0173 - mean_absolute_error: 0.0134 - val_loss: 0.0311 - val_root_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.0268
# Epoch 132/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0242 - root_mean_squared_error: 0.0245 - mean_absolute_error: 0.0203 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0337 - val_mean_absolute_error: 0.0263
# Epoch 133/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0250 - root_mean_squared_error: 0.0255 - mean_absolute_error: 0.0208 - val_loss: 0.0367 - val_root_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.0290
# Epoch 134/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0175 - root_mean_squared_error: 0.0176 - mean_absolute_error: 0.0126 - val_loss: 0.0312 - val_root_mean_squared_error: 0.0312 - val_mean_absolute_error: 0.0276
# Epoch 135/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0211 - root_mean_squared_error: 0.0212 - mean_absolute_error: 0.0174 - val_loss: 0.0364 - val_root_mean_squared_error: 0.0364 - val_mean_absolute_error: 0.0279
# Epoch 136/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0238 - root_mean_squared_error: 0.0243 - mean_absolute_error: 0.0201 - val_loss: 0.0473 - val_root_mean_squared_error: 0.0473 - val_mean_absolute_error: 0.0346
# Epoch 137/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0300 - root_mean_squared_error: 0.0305 - mean_absolute_error: 0.0235 - val_loss: 0.0405 - val_root_mean_squared_error: 0.0405 - val_mean_absolute_error: 0.0294
# Epoch 138/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0233 - root_mean_squared_error: 0.0236 - mean_absolute_error: 0.0188 - val_loss: 0.0416 - val_root_mean_squared_error: 0.0416 - val_mean_absolute_error: 0.0322
# Epoch 139/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0222 - root_mean_squared_error: 0.0229 - mean_absolute_error: 0.0172 - val_loss: 0.0309 - val_root_mean_squared_error: 0.0309 - val_mean_absolute_error: 0.0266
# Epoch 140/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0197 - root_mean_squared_error: 0.0197 - mean_absolute_error: 0.0161 - val_loss: 0.0299 - val_root_mean_squared_error: 0.0299 - val_mean_absolute_error: 0.0232
# Epoch 141/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0191 - root_mean_squared_error: 0.0191 - mean_absolute_error: 0.0160 - val_loss: 0.0315 - val_root_mean_squared_error: 0.0315 - val_mean_absolute_error: 0.0259
# Epoch 142/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0168 - root_mean_squared_error: 0.0172 - mean_absolute_error: 0.0136 - val_loss: 0.0353 - val_root_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.0273
# Epoch 143/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0178 - root_mean_squared_error: 0.0179 - mean_absolute_error: 0.0132 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.0242
# Epoch 144/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0164 - root_mean_squared_error: 0.0171 - mean_absolute_error: 0.0132 - val_loss: 0.0314 - val_root_mean_squared_error: 0.0314 - val_mean_absolute_error: 0.0252
# Epoch 145/256
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0217 - root_mean_squared_error: 0.0218 - mean_absolute_error: 0.0180 - val_loss: 0.0293 - val_root_mean_squared_error: 0.0293 - val_mean_absolute_error: 0.0248
# Epoch 146/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0223 - root_mean_squared_error: 0.0234 - mean_absolute_error: 0.0176 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0320 - val_mean_absolute_error: 0.0275
# Epoch 147/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0231 - root_mean_squared_error: 0.0244 - mean_absolute_error: 0.0197 - val_loss: 0.0356 - val_root_mean_squared_error: 0.0356 - val_mean_absolute_error: 0.0283
# Epoch 148/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0231 - root_mean_squared_error: 0.0232 - mean_absolute_error: 0.0191 - val_loss: 0.0304 - val_root_mean_squared_error: 0.0304 - val_mean_absolute_error: 0.0272
# Epoch 149/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0218 - root_mean_squared_error: 0.0236 - mean_absolute_error: 0.0178 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0228
# Epoch 150/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0262 - root_mean_squared_error: 0.0277 - mean_absolute_error: 0.0193 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0351 - val_mean_absolute_error: 0.0284
# Epoch 151/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0246 - root_mean_squared_error: 0.0248 - mean_absolute_error: 0.0209 - val_loss: 0.0388 - val_root_mean_squared_error: 0.0388 - val_mean_absolute_error: 0.0316
# Epoch 152/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0268 - root_mean_squared_error: 0.0275 - mean_absolute_error: 0.0230 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0320 - val_mean_absolute_error: 0.0227
# Epoch 153/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0246 - root_mean_squared_error: 0.0254 - mean_absolute_error: 0.0199 - val_loss: 0.0416 - val_root_mean_squared_error: 0.0416 - val_mean_absolute_error: 0.0307
# Epoch 154/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0297 - root_mean_squared_error: 0.0303 - mean_absolute_error: 0.0242 - val_loss: 0.0281 - val_root_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.0245
# Epoch 155/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0172 - root_mean_squared_error: 0.0172 - mean_absolute_error: 0.0147 - val_loss: 0.0295 - val_root_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.0244
# Epoch 156/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0166 - root_mean_squared_error: 0.0172 - mean_absolute_error: 0.0131 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0229
# Epoch 157/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0169 - root_mean_squared_error: 0.0169 - mean_absolute_error: 0.0129 - val_loss: 0.0260 - val_root_mean_squared_error: 0.0260 - val_mean_absolute_error: 0.0219
# Epoch 158/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0178 - root_mean_squared_error: 0.0180 - mean_absolute_error: 0.0137 - val_loss: 0.0363 - val_root_mean_squared_error: 0.0363 - val_mean_absolute_error: 0.0278
# Epoch 159/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0228 - root_mean_squared_error: 0.0254 - mean_absolute_error: 0.0192 - val_loss: 0.0564 - val_root_mean_squared_error: 0.0564 - val_mean_absolute_error: 0.0434
# Epoch 160/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0347 - root_mean_squared_error: 0.0354 - mean_absolute_error: 0.0273 - val_loss: 0.0490 - val_root_mean_squared_error: 0.0490 - val_mean_absolute_error: 0.0422
# Epoch 161/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0302 - root_mean_squared_error: 0.0310 - mean_absolute_error: 0.0260 - val_loss: 0.0414 - val_root_mean_squared_error: 0.0414 - val_mean_absolute_error: 0.0342
# Epoch 162/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0260 - root_mean_squared_error: 0.0268 - mean_absolute_error: 0.0208 - val_loss: 0.0383 - val_root_mean_squared_error: 0.0383 - val_mean_absolute_error: 0.0289
# Epoch 163/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0251 - root_mean_squared_error: 0.0266 - mean_absolute_error: 0.0196 - val_loss: 0.0358 - val_root_mean_squared_error: 0.0358 - val_mean_absolute_error: 0.0280
# Epoch 164/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0231 - root_mean_squared_error: 0.0232 - mean_absolute_error: 0.0180 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0227
# Epoch 165/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0237 - root_mean_squared_error: 0.0249 - mean_absolute_error: 0.0197 - val_loss: 0.0291 - val_root_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.0215
# Epoch 166/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0200 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0150 - val_loss: 0.0384 - val_root_mean_squared_error: 0.0384 - val_mean_absolute_error: 0.0280
# Epoch 167/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0223 - root_mean_squared_error: 0.0237 - mean_absolute_error: 0.0181 - val_loss: 0.0270 - val_root_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0232
# Epoch 168/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0182 - root_mean_squared_error: 0.0184 - mean_absolute_error: 0.0144 - val_loss: 0.0251 - val_root_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.0205
# Epoch 169/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0166 - root_mean_squared_error: 0.0168 - mean_absolute_error: 0.0124 - val_loss: 0.0289 - val_root_mean_squared_error: 0.0289 - val_mean_absolute_error: 0.0250
# Epoch 170/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0238 - root_mean_squared_error: 0.0266 - mean_absolute_error: 0.0208 - val_loss: 0.0324 - val_root_mean_squared_error: 0.0324 - val_mean_absolute_error: 0.0269
# Epoch 171/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0188 - root_mean_squared_error: 0.0190 - mean_absolute_error: 0.0156 - val_loss: 0.0314 - val_root_mean_squared_error: 0.0314 - val_mean_absolute_error: 0.0248
# Epoch 172/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0187 - root_mean_squared_error: 0.0189 - mean_absolute_error: 0.0134 - val_loss: 0.0285 - val_root_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.0222
# Epoch 173/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0211 - root_mean_squared_error: 0.0212 - mean_absolute_error: 0.0173 - val_loss: 0.0277 - val_root_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0206
# Epoch 174/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0216 - root_mean_squared_error: 0.0233 - mean_absolute_error: 0.0177 - val_loss: 0.0394 - val_root_mean_squared_error: 0.0394 - val_mean_absolute_error: 0.0307
# Epoch 175/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0231 - root_mean_squared_error: 0.0237 - mean_absolute_error: 0.0185 - val_loss: 0.0244 - val_root_mean_squared_error: 0.0244 - val_mean_absolute_error: 0.0202
# Epoch 176/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0181 - root_mean_squared_error: 0.0186 - mean_absolute_error: 0.0155 - val_loss: 0.0254 - val_root_mean_squared_error: 0.0254 - val_mean_absolute_error: 0.0199
# Epoch 177/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0151 - root_mean_squared_error: 0.0156 - mean_absolute_error: 0.0112 - val_loss: 0.0489 - val_root_mean_squared_error: 0.0489 - val_mean_absolute_error: 0.0371
# Epoch 178/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0308 - root_mean_squared_error: 0.0318 - mean_absolute_error: 0.0244 - val_loss: 0.0330 - val_root_mean_squared_error: 0.0330 - val_mean_absolute_error: 0.0266
# Epoch 179/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0211 - root_mean_squared_error: 0.0216 - mean_absolute_error: 0.0181 - val_loss: 0.0244 - val_root_mean_squared_error: 0.0244 - val_mean_absolute_error: 0.0208
# Epoch 180/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0258 - root_mean_squared_error: 0.0284 - mean_absolute_error: 0.0195 - val_loss: 0.0304 - val_root_mean_squared_error: 0.0304 - val_mean_absolute_error: 0.0239
# Epoch 181/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0254 - root_mean_squared_error: 0.0273 - mean_absolute_error: 0.0183 - val_loss: 0.0353 - val_root_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.0272
# Epoch 182/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0281 - root_mean_squared_error: 0.0290 - mean_absolute_error: 0.0234 - val_loss: 0.0562 - val_root_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.0461
# Epoch 183/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0534 - root_mean_squared_error: 0.0538 - mean_absolute_error: 0.0473 - val_loss: 0.0296 - val_root_mean_squared_error: 0.0296 - val_mean_absolute_error: 0.0231
# Epoch 184/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0280 - root_mean_squared_error: 0.0308 - mean_absolute_error: 0.0241 - val_loss: 0.0329 - val_root_mean_squared_error: 0.0329 - val_mean_absolute_error: 0.0264
# Epoch 185/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0283 - root_mean_squared_error: 0.0291 - mean_absolute_error: 0.0225 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0222
# Epoch 186/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0171 - root_mean_squared_error: 0.0172 - mean_absolute_error: 0.0136 - val_loss: 0.0387 - val_root_mean_squared_error: 0.0387 - val_mean_absolute_error: 0.0322
# Epoch 187/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0163 - root_mean_squared_error: 0.0165 - mean_absolute_error: 0.0136 - val_loss: 0.0384 - val_root_mean_squared_error: 0.0384 - val_mean_absolute_error: 0.0287
# Epoch 188/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0268 - root_mean_squared_error: 0.0280 - mean_absolute_error: 0.0220 - val_loss: 0.0316 - val_root_mean_squared_error: 0.0316 - val_mean_absolute_error: 0.0260
# Epoch 189/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0201 - root_mean_squared_error: 0.0204 - mean_absolute_error: 0.0161 - val_loss: 0.0294 - val_root_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.0233
# Epoch 190/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0163 - root_mean_squared_error: 0.0164 - mean_absolute_error: 0.0119 - val_loss: 0.0278 - val_root_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0226
# Epoch 191/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0141 - root_mean_squared_error: 0.0141 - mean_absolute_error: 0.0098 - val_loss: 0.0278 - val_root_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0226
# Epoch 192/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0208 - root_mean_squared_error: 0.0222 - mean_absolute_error: 0.0153 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0337 - val_mean_absolute_error: 0.0251
# Epoch 193/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0234 - root_mean_squared_error: 0.0244 - mean_absolute_error: 0.0190 - val_loss: 0.0326 - val_root_mean_squared_error: 0.0326 - val_mean_absolute_error: 0.0258
# Epoch 194/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0167 - root_mean_squared_error: 0.0169 - mean_absolute_error: 0.0134 - val_loss: 0.0279 - val_root_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.0230
# Epoch 195/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0135 - root_mean_squared_error: 0.0135 - mean_absolute_error: 0.0108 - val_loss: 0.0245 - val_root_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0211
# Epoch 196/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0171 - root_mean_squared_error: 0.0173 - mean_absolute_error: 0.0137 - val_loss: 0.0279 - val_root_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.0212
# Epoch 197/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0150 - root_mean_squared_error: 0.0169 - mean_absolute_error: 0.0120 - val_loss: 0.0317 - val_root_mean_squared_error: 0.0317 - val_mean_absolute_error: 0.0251
# Epoch 198/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0171 - root_mean_squared_error: 0.0177 - mean_absolute_error: 0.0132 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0223
# Epoch 199/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0145 - root_mean_squared_error: 0.0147 - mean_absolute_error: 0.0103 - val_loss: 0.0354 - val_root_mean_squared_error: 0.0354 - val_mean_absolute_error: 0.0283
# Epoch 200/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0184 - root_mean_squared_error: 0.0196 - mean_absolute_error: 0.0151 - val_loss: 0.0294 - val_root_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.0242
# Epoch 201/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0205 - root_mean_squared_error: 0.0208 - mean_absolute_error: 0.0157 - val_loss: 0.0275 - val_root_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0226
# Epoch 202/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0233 - root_mean_squared_error: 0.0261 - mean_absolute_error: 0.0191 - val_loss: 0.0359 - val_root_mean_squared_error: 0.0359 - val_mean_absolute_error: 0.0303
# Epoch 203/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0207 - root_mean_squared_error: 0.0209 - mean_absolute_error: 0.0174 - val_loss: 0.0430 - val_root_mean_squared_error: 0.0430 - val_mean_absolute_error: 0.0347
# Epoch 204/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0364 - root_mean_squared_error: 0.0379 - mean_absolute_error: 0.0326 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0497 - val_mean_absolute_error: 0.0387
# Epoch 205/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0324 - root_mean_squared_error: 0.0329 - mean_absolute_error: 0.0279 - val_loss: 0.0492 - val_root_mean_squared_error: 0.0492 - val_mean_absolute_error: 0.0386
# Epoch 206/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0489 - root_mean_squared_error: 0.0506 - mean_absolute_error: 0.0381 - val_loss: 0.0379 - val_root_mean_squared_error: 0.0379 - val_mean_absolute_error: 0.0302
# Epoch 207/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0371 - root_mean_squared_error: 0.0394 - mean_absolute_error: 0.0308 - val_loss: 0.0353 - val_root_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.0307
# Epoch 208/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0376 - root_mean_squared_error: 0.0387 - mean_absolute_error: 0.0351 - val_loss: 0.0280 - val_root_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.0224
# Epoch 209/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0361 - root_mean_squared_error: 0.0401 - mean_absolute_error: 0.0327 - val_loss: 0.0411 - val_root_mean_squared_error: 0.0411 - val_mean_absolute_error: 0.0341
# Epoch 210/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0310 - root_mean_squared_error: 0.0316 - mean_absolute_error: 0.0255 - val_loss: 0.0262 - val_root_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0215
# Epoch 211/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0294 - root_mean_squared_error: 0.0305 - mean_absolute_error: 0.0222 - val_loss: 0.0403 - val_root_mean_squared_error: 0.0403 - val_mean_absolute_error: 0.0306
# Epoch 212/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0322 - root_mean_squared_error: 0.0327 - mean_absolute_error: 0.0256 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0196
# Epoch 213/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0326 - root_mean_squared_error: 0.0343 - mean_absolute_error: 0.0288 - val_loss: 0.0415 - val_root_mean_squared_error: 0.0415 - val_mean_absolute_error: 0.0328
# Epoch 214/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0274 - root_mean_squared_error: 0.0288 - mean_absolute_error: 0.0229 - val_loss: 0.0312 - val_root_mean_squared_error: 0.0312 - val_mean_absolute_error: 0.0249
# Epoch 215/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0264 - root_mean_squared_error: 0.0281 - mean_absolute_error: 0.0205 - val_loss: 0.0331 - val_root_mean_squared_error: 0.0331 - val_mean_absolute_error: 0.0258
# Epoch 216/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0358 - root_mean_squared_error: 0.0375 - mean_absolute_error: 0.0296 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0199
# Epoch 217/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0343 - root_mean_squared_error: 0.0364 - mean_absolute_error: 0.0300 - val_loss: 0.0434 - val_root_mean_squared_error: 0.0434 - val_mean_absolute_error: 0.0340
# Epoch 218/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0277 - root_mean_squared_error: 0.0284 - mean_absolute_error: 0.0222 - val_loss: 0.0306 - val_root_mean_squared_error: 0.0306 - val_mean_absolute_error: 0.0242
# Epoch 219/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0308 - root_mean_squared_error: 0.0316 - mean_absolute_error: 0.0237 - val_loss: 0.0435 - val_root_mean_squared_error: 0.0435 - val_mean_absolute_error: 0.0319
# Epoch 220/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0250 - root_mean_squared_error: 0.0252 - mean_absolute_error: 0.0197 - val_loss: 0.0275 - val_root_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0212
# Epoch 221/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0266 - root_mean_squared_error: 0.0277 - mean_absolute_error: 0.0221 - val_loss: 0.0287 - val_root_mean_squared_error: 0.0287 - val_mean_absolute_error: 0.0223
# Epoch 222/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0310 - root_mean_squared_error: 0.0335 - mean_absolute_error: 0.0265 - val_loss: 0.0291 - val_root_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.0230
# Epoch 223/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0288 - root_mean_squared_error: 0.0296 - mean_absolute_error: 0.0233 - val_loss: 0.0392 - val_root_mean_squared_error: 0.0392 - val_mean_absolute_error: 0.0298
# Epoch 224/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0230 - root_mean_squared_error: 0.0234 - mean_absolute_error: 0.0191 - val_loss: 0.0295 - val_root_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.0233
# Epoch 225/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0164 - root_mean_squared_error: 0.0166 - mean_absolute_error: 0.0128 - val_loss: 0.0302 - val_root_mean_squared_error: 0.0302 - val_mean_absolute_error: 0.0229
# Epoch 226/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0176 - root_mean_squared_error: 0.0179 - mean_absolute_error: 0.0135 - val_loss: 0.0345 - val_root_mean_squared_error: 0.0345 - val_mean_absolute_error: 0.0257
# Epoch 227/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0150 - root_mean_squared_error: 0.0150 - mean_absolute_error: 0.0120 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0261 - val_mean_absolute_error: 0.0218
# Epoch 228/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0135 - root_mean_squared_error: 0.0136 - mean_absolute_error: 0.0114 - val_loss: 0.0271 - val_root_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0215
# Epoch 229/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0209 - root_mean_squared_error: 0.0209 - mean_absolute_error: 0.0170 - val_loss: 0.0373 - val_root_mean_squared_error: 0.0373 - val_mean_absolute_error: 0.0286
# Epoch 230/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0152 - root_mean_squared_error: 0.0157 - mean_absolute_error: 0.0109 - val_loss: 0.0258 - val_root_mean_squared_error: 0.0258 - val_mean_absolute_error: 0.0220
# Epoch 231/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0157 - root_mean_squared_error: 0.0161 - mean_absolute_error: 0.0122 - val_loss: 0.0305 - val_root_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.0240
# Epoch 232/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0157 - root_mean_squared_error: 0.0160 - mean_absolute_error: 0.0132 - val_loss: 0.0282 - val_root_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.0229
# Epoch 233/256
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0169 - root_mean_squared_error: 0.0180 - mean_absolute_error: 0.0132 - val_loss: 0.0459 - val_root_mean_squared_error: 0.0459 - val_mean_absolute_error: 0.0375
# Epoch 234/256
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0301 - root_mean_squared_error: 0.0317 - mean_absolute_error: 0.0245 - val_loss: 0.0367 - val_root_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.0283
# Epoch 235/256
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0375 - root_mean_squared_error: 0.0377 - mean_absolute_error: 0.0336 - val_loss: 0.0419 - val_root_mean_squared_error: 0.0419 - val_mean_absolute_error: 0.0329
# Epoch 236/256
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0327 - root_mean_squared_error: 0.0333 - mean_absolute_error: 0.0280 - val_loss: 0.0274 - val_root_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0211
# Epoch 237/256
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0220 - root_mean_squared_error: 0.0230 - mean_absolute_error: 0.0181 - val_loss: 0.0408 - val_root_mean_squared_error: 0.0408 - val_mean_absolute_error: 0.0297
# Epoch 238/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0269 - root_mean_squared_error: 0.0278 - mean_absolute_error: 0.0218 - val_loss: 0.0340 - val_root_mean_squared_error: 0.0340 - val_mean_absolute_error: 0.0257
# Epoch 239/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0239 - root_mean_squared_error: 0.0248 - mean_absolute_error: 0.0188 - val_loss: 0.0518 - val_root_mean_squared_error: 0.0518 - val_mean_absolute_error: 0.0429
# Epoch 240/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0422 - root_mean_squared_error: 0.0425 - mean_absolute_error: 0.0356 - val_loss: 0.0262 - val_root_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0215
# Epoch 241/256
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0218 - root_mean_squared_error: 0.0224 - mean_absolute_error: 0.0188 - val_loss: 0.0373 - val_root_mean_squared_error: 0.0373 - val_mean_absolute_error: 0.0291
# Epoch 242/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0301 - root_mean_squared_error: 0.0319 - mean_absolute_error: 0.0253 - val_loss: 0.0315 - val_root_mean_squared_error: 0.0315 - val_mean_absolute_error: 0.0240
# Epoch 243/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0255 - root_mean_squared_error: 0.0279 - mean_absolute_error: 0.0220 - val_loss: 0.0348 - val_root_mean_squared_error: 0.0348 - val_mean_absolute_error: 0.0287
# Epoch 244/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0193 - root_mean_squared_error: 0.0198 - mean_absolute_error: 0.0159 - val_loss: 0.0257 - val_root_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.0215
# Epoch 245/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0158 - root_mean_squared_error: 0.0159 - mean_absolute_error: 0.0123 - val_loss: 0.0270 - val_root_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0223
# Epoch 246/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0168 - root_mean_squared_error: 0.0170 - mean_absolute_error: 0.0139 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0351 - val_mean_absolute_error: 0.0293
# Epoch 247/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0196 - root_mean_squared_error: 0.0196 - mean_absolute_error: 0.0161 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0337 - val_mean_absolute_error: 0.0285
# Epoch 248/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0220 - root_mean_squared_error: 0.0222 - mean_absolute_error: 0.0180 - val_loss: 0.0346 - val_root_mean_squared_error: 0.0346 - val_mean_absolute_error: 0.0278
# Epoch 249/256
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0212 - root_mean_squared_error: 0.0224 - mean_absolute_error: 0.0169 - val_loss: 0.0298 - val_root_mean_squared_error: 0.0298 - val_mean_absolute_error: 0.0199
# Epoch 250/256
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0259 - root_mean_squared_error: 0.0270 - mean_absolute_error: 0.0218 - val_loss: 0.0417 - val_root_mean_squared_error: 0.0417 - val_mean_absolute_error: 0.0309
# Epoch 251/256
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0255 - root_mean_squared_error: 0.0258 - mean_absolute_error: 0.0213 - val_loss: 0.0441 - val_root_mean_squared_error: 0.0441 - val_mean_absolute_error: 0.0372
# Epoch 252/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0301 - root_mean_squared_error: 0.0318 - mean_absolute_error: 0.0254 - val_loss: 0.0549 - val_root_mean_squared_error: 0.0549 - val_mean_absolute_error: 0.0457
# Epoch 253/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0346 - root_mean_squared_error: 0.0369 - mean_absolute_error: 0.0306 - val_loss: 0.0343 - val_root_mean_squared_error: 0.0343 - val_mean_absolute_error: 0.0280
# Epoch 254/256
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0223 - root_mean_squared_error: 0.0224 - mean_absolute_error: 0.0187 - val_loss: 0.0390 - val_root_mean_squared_error: 0.0390 - val_mean_absolute_error: 0.0288
# Epoch 255/256
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0223 - root_mean_squared_error: 0.0235 - mean_absolute_error: 0.0174 - val_loss: 0.0286 - val_root_mean_squared_error: 0.0286 - val_mean_absolute_error: 0.0201
# Epoch 256/256
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0237 - root_mean_squared_error: 0.0241 - mean_absolute_error: 0.0202 - val_loss: 0.0339 - val_root_mean_squared_error: 0.0339 - val_mean_absolute_error: 0.0270

# %%
# Interpreting results
loss, rmse, err = NN_model.evaluate(X_test, Y_test)
# wandb.finish()
print(rmse * range_y)
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0214 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0160
# 381181213347.4946

# %% [markdown]
# # Appendix
#
# ## A.1 Frequentist Implementation of Linear Model using Sklearn
#
# In this code block, we attempt to bootstrap a simple regression model using `sklearn`. We decided against `sklearn`, since it didn't allow for us to adjust the priors of our input parameters. Furthermore, the package lacked out-of-the-box measures for goodness-of-fit, such as the log-likelihood test and Pearson chi-squared test.

# %%
# Bootstrapping the MAE for a frequentist linear regression model 
values = df.values
n_iterations = 1000
n_size = int(len(data) * 0.50) 

# run bootstrap
stats = []
for i in range(n_iterations):
    # Train, test, validation split into 60% train, 20% test, 20% split
    train, validate, test = np.split(df.sample(frac=1, replace=True), 
                       [int(.6*len(df)), int(.8*len(df))])
    
    # Linear regression
    X = train[prediction_columns].to_numpy()
    Y = train[y_val].to_numpy()

    linear_regressor = LinearRegression(positive=True)  # create object for the class
    linear_regressor.fit(X, Y)  # perform linear regression
    
    # Fit model and evaluate MAE 
    Y_pred = linear_regressor.predict(X)  # make predictions
    stats.append(np.sqrt(metrics.mean_squared_error(Y, Y_pred)))
    
# Plotting the range of MAE
plt.hist(stats)
plt.ylabel("Frequency")
plt.xlabel("MAE")
plt.title("Distribution of Bootstrap Estimates of RMSE")
# Out:
# Text(0.5, 1.0, 'Distribution of Bootstrap Estimates of RMSE')

# %% [markdown]
# ## A.2 Eliminating Collinearity via Principal Component Analysis
#
# In the next two code blocks, we attempt to build a simple linear regression model using `statsmodels`, and eliminate collinearity amongst input variables using Principal Component Analysis. We decided against PCA, since we lose the ability to attribute each "principal axis" to a singular input feature. In particular, when performing posterior predictive checking for our Bayesian model, we're unable to derive credible intervals for individual features––we can only interpret credible intervals for each principal axis.
#
# From the frequentist point of view, PCA yielded an RMSE of $\approx 0.064$, whereas the implementation using VIF yielded an RMSE of $\approx 0.08$. For the purposes of our research question, we're optimizing for interpretability over a slight improvement in performance.

# %%
# PCA
train, test = train_test_split(renamed_df, test_size=config['test_size'])
n_components = 4
pca = PCA(n_components)
pca.fit(train[renamed_features])
pca_train_df = pd.DataFrame(pca.transform(train[renamed_features]), 
                      columns=['PCA%i' % i for i in range(n_components)], index=train.index)

# Part 1: Frequentist Implementation w/ PCA

# Compute formula with only the non-colinear variables; consider interaction variables
formula = f'y ~ ' + ' + '.join(list(pca_train_df.columns))
print(formula)
pca_train_df['y'] = train['y']
glm_ = smf.glm(formula=formula,
              data=pca_train_df,
              family=sm.families.Gaussian())

glm = glm_.fit()
print(glm.summary()) # Passes pearson chi_squared test, but not log likelihood test

# Extracting RMSE
pca_test_df = pd.DataFrame(pca.transform(test[renamed_features]), 
                      columns=['PCA%i' % i for i in range(n_components)], index=test.index)
y_true = np.array(test['y'])
y_hat = glm.predict(pca_test_df)
rmse_freq = sm.tools.eval_measures.rmse(y_true, y_hat)
rmse_freq
# Out:
# y ~ PCA0 + PCA1 + PCA2 + PCA3
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   56
# Model:                            GLM   Df Residuals:                       51
# Model Family:                Gaussian   Df Model:                            4
# Link Function:               identity   Scale:                       0.0031705
# Method:                          IRLS   Log-Likelihood:                 84.266
# Date:                Mon, 09 May 2022   Deviance:                      0.16170
# Time:                        19:55:01   Pearson chi2:                    0.162
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4593      0.008     61.038      0.000       0.445       0.474
# PCA0          -0.5012      0.016    -31.930      0.000      -0.532      -0.470
# PCA1           0.2016      0.019     10.809      0.000       0.165       0.238
# PCA2          -0.5166      0.061     -8.515      0.000      -0.635      -0.398
# PCA3           0.5641      0.099      5.676      0.000       0.369       0.759
# ==============================================================================
# 0.06786628841628374

# %%
# Part 2: Bayesian Implementation w/ PCA
# We can reuse the formula derived in the frequentist approach to construct a Bayesian GLM
print(formula)

bglm = pm.Model()

pca_full_df = pd.DataFrame(pca.transform(renamed_df[renamed_features]), 
                      columns=['PCA%i' % i for i in range(n_components)], index=renamed_df.index)
pca_full_df['y'] = renamed_df['y']

with bglm as gaussian_model:
    # Normally distributed priors
    family = pm.glm.families.Normal()
    # create the model 
    pm.GLM.from_formula(formula,data=pca_full_df,family=family)
    # sample
    gaussian_trace = pm.sample(1000,return_inferencedata=True)
    
summary = avz.summary(gaussian_trace) 
print(summary)

# Draw posterior predictive samples from linear model 
with gaussian_model:
    gaussian_ppc = pm.sample_posterior_predictive(
        gaussian_trace, var_names=['PCA%i' % i for i in range(n_components)] + ['y'] + ['Intercept']
    )
    
# Perform posterior predictive checking across all features
name_dict = {v: k for k, v in rename_dict.items()}
for col in ['PCA%i' % i for i in range(n_components)]:
    # Compute the posterior regression function (y hat values) for the linear GLM
    y_hat_gaussian = np.exp(
        np.outer(gaussian_ppc[col], pca_full_df[col])
        + gaussian_ppc["Intercept"][:,np.newaxis]
    )
    
    # Plot posterior predictive checks, construct credible interval 
    _, ax = plt.subplots(figsize = (4,4))

    ax.plot(pca_full_df[col], df[y_val], "o", ms=4, alpha=0.4, label="Data")
    avz.plot_hdi(
        pca_full_df[col],
        y_hat_gaussian,
        ax=ax,
        hdi_prob=0.95,
        fill_kwargs={"alpha": 0.8, "label": "95% credible interval for reg fn"},
    )
    avz.plot_hdi(
        pca_full_df[col],
        gaussian_ppc["y"],
        ax=ax,
        hdi_prob=0.95,
        fill_kwargs={"alpha": 0.8, "color": "#a1dab4", "label": "95% credible interval for y_rep's"},
    )

    ax.set_xlabel(f"{col}")
    ax.set_ylabel("GDP (z-score)")
    ax.set_title("Posterior predictive checks")
    ax.legend(fontsize=10);
# Out:
# y ~ PCA0 + PCA1 + PCA2 + PCA3
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, PCA3, PCA2, PCA1, PCA0, Intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:03<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 4 seconds.
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept  0.464  0.007   0.451    0.477      0.000    0.000    5069.0
# PCA0      -0.508  0.014  -0.535   -0.483      0.000    0.000    5843.0
# PCA1       0.215  0.017   0.185    0.247      0.000    0.000    5166.0
# PCA2      -0.482  0.058  -0.590   -0.376      0.001    0.001    5289.0
# PCA3       0.502  0.090   0.326    0.671      0.001    0.001    5539.0
# sd         0.060  0.005   0.051    0.071      0.000    0.000    5691.0
#
#            ess_tail  r_hat
# Intercept    3252.0    1.0
# PCA0         2982.0    1.0
# PCA1         2959.0    1.0
# PCA2         3369.0    1.0
# PCA3         3150.0    1.0
# sd           3042.0    1.0
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:07<00:00]
#     </div>

# %% [markdown]
# ## A.3 Bootstrapping Confidence Intervals for invididual features
#
# In the next code block, we attempt to use bootstrap to manually construct confidence intervals and standard errors for each feature in our dataset. We decided against this technique, since `statsmodels` gave confidence intervals and standard errors for each parameters already during its sampling phase.

# %%
import numpy.random as rnd
def bootstrap_xy(X, y, fnc, w=None, B=1000, plot=True):
    d = X.shape[1]
    N = X.shape[0]
    w_hat = fnc(X, y)
    w_boot = np.zeros(shape=(B,d))
    for b in range(B):
        bootstrap_indices = rnd.choice(np.arange(N), N)
        bootstrap_X = X.iloc[bootstrap_indices, :]
        bootstrap_y = y.iloc[bootstrap_indices]
        w_boot[b,:] = fnc(bootstrap_X, bootstrap_y)
    if plot:
        plt.scatter(w_boot[:,0], w_boot[:,1], c='b')
        plt.scatter(w_hat[0], w_hat[1], c='r', marker='x', s=300)
        if w:
            plt.scatter(w[0], w[1], c='g', marker='x', s=300)
        plt.show()
    return w_boot

def lin_model(x, y):
    model = sm.GLM(
        y, x,
        family=sm.families.Gaussian()
    )
    results = model.fit()
    params = results.params
    
    return params

w_gaussian_boot = bootstrap_xy(sm.add_constant(renamed_df.x1), renamed_df.y, lin_model)
beta_0, beta_1 = w_gaussian_boot.std(axis = 0)
print(f"Bootstrap std error for const: {beta_0:.3f}")
print(f"Bootstrap std error for variable: {beta_1:.3f}")
# Out:
# Bootstrap std error for const: 0.104
# Bootstrap std error for variable: 0.132
